# %%
from utils.trajectories import get_attractor_trajectory
from utils.plots import plot_trajectory
from systems import chua_rk4, chua_right_part

plot_trajectory(get_attractor_trajectory(chua_rk4, chua_right_part,
                                         [-3.43086445, -1.78514213, -4.73140597], [8.4, 12, 0, -0.12, -1.15],
                                         0.01, 10, 10, lambda x, y: x[1], lambda x, y: [0, 1, 0]))
# Out:
# /home/machcreator/neuromap_sync/venv/lib/python3.12/site-packages/numpy/linalg/_linalg.py:2767: RuntimeWarning: overflow encountered in dot
#   sqnorm = x.dot(x)
# /home/machcreator/neuromap_sync/utils/rk4.py:15: RuntimeWarning: overflow encountered in add
#   new_state = state + (h / 6) * (k1 + 2*k2 + 2*k3 + k4)
# /home/machcreator/neuromap_sync/systems/chua_rk4.py:10: RuntimeWarning: invalid value encountered in scalar subtract
#   f     = m1 * x + (m0-m1) * (abs(x+1)-abs(x-1)) / 2
# /home/machcreator/neuromap_sync/systems/chua_rk4.py:13: RuntimeWarning: invalid value encountered in scalar multiply
#   z_dot =  - (beta * y + gamma * z)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 from utils.plots import plot_trajectory
#       3 from systems import chua_rk4, chua_right_part
# ...

# %%
states = [
    np.array([-3.43086445, -1.78514213, -4.73140597]),
    np.array([-3.91055058, 1.14827257, 4.0497644]),
    np.array([-0.06298417, -1.53119096, 2.58772816]),
    np.array([ 2.98994669e+00, 4.49008896e-04, -4.52306348e+00])
]
