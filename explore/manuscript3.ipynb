# %%
from utils import plot_trajectory, get_attractor_trajectory
from systems import vdp_mod1_rk4, vdp_mod1_right_part

plot_trajectory(get_attractor_trajectory(vdp_mod1_rk4, vdp_mod1_right_part,
                                         [5, -50.1], [-1.78, 0.07],
                                         0.01, 300, 200, lambda x, y: x[1], lambda x, y: [0, 1]))
